# %% [markdown]
# <a href="https://colab.research.google.com/github/betsialo/raspberry651120/blob/main/lesson5%5Clesson5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
body = {
    "messages": [
        {
            "role": "user",
            "content": "天空為什麼是藍的?"
        },
        {
            "role": "assistant",
            "content": "因為光的散射..."
        },
        {
            "role": "user",
            "content": "可以解釋簡單一點嗎?"
        }
    ]
}

#body.get("messages",[])[-1].get("content","")
messages = body.get("messages",[])
not messages

last_message = messages[-1]
message_content = last_message.get("content", "")
message_len = len(message_content)
